# %% [markdown]
# # 9 Unsupervised Learning Techniques

# %% [markdown]
# ## Clustering

# %%
from sklearn.datasets import make_blobs

# %%
X,y=make_blobs(n_samples=1000,centers=5, random_state=42)

# %%
import matplotlib.pyplot as plt
plt.scatter(X[:,0],X[:,1],c=y,cmap='plasma',alpha=0.4)

# %%
from sklearn.cluster import KMeans
k=5
kmeans=KMeans(n_clusters=k)
y_pred = kmeans.fit_predict(X)

# %%
y[:10],'/n',y_pred[:10]
# Out:
# (array([1, 1, 2, 1, 4, 2, 3, 4, 1, 4]),
#  '/n',
#  array([0, 0, 2, 0, 4, 2, 3, 4, 0, 4]))

# %%
plt.scatter(X[:,0],X[:,1],c=y_pred,cmap='plasma',alpha=0.4)

# %%
y_pred is kmeans.labels_
# Out:
# True

# %%
centers = kmeans.cluster_centers_

# %%
plt.scatter(centers[:,0],centers[:,1])

# %%
import numpy as np
X_new = np.array([[0,2],[3,2],[-3,3],[-3,2.5]])
y_pred2 = kmeans.predict(X_new)

# %%
def plot_centroids(cetroids,weights=None,circle_color='w',cross_color='k'):
    if weights is not None:
        cetroids = cetroids[weigths>weights.max()/10]
    plt.scatter(centroids[:,0],centroids[:1],marker='o',s=35,linewidths=8,color=circle_color,zorder=10,alpha=0.9)
    plt.scatter(centroids[:,0],centroids[:1],marker='x',s=2,linewidths=12,color=circle_color,zorder=10,alpha=1)

# %%
def plot_decision_boundaries(clusterer, X, resolution=1000, show_centroids=True,
                             show_xlabels=True, show_ylabels=True):
    mins = X.min(axis=0) - 0.1
    maxs = X.max(axis=0) + 0.1
    xx, yy = np.meshgrid(np.linspace(mins[0], maxs[0], resolution),
                         np.linspace(mins[1], maxs[1], resolution))
    Z = clusterer.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    plt.contourf(Z, extent=(mins[0], maxs[0], mins[1], maxs[1]),
                cmap="Pastel2")
    plt.contour(Z, extent=(mins[0], maxs[0], mins[1], maxs[1]),
                linewidths=1, colors='k')

# %%
X.min(axis=0)
# Out:
# array([-11.39224889,  -9.77636497])

# %%
X.min(axis=0) -0.1
# Out:
# array([-11.49224889,  -9.87636497])

# %%
plot_decision_boundaries(kmeans,X)
